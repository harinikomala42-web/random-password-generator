# %%
#random password generator
import random
print("welcome to random password generator!")
randomchars = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz1234567890!@#$%^&*"
nbrofpwds =int(input("please enter a number of passwords to be generated:"))
pwdlen =int(input("please enter the lenght of the password needed:"))
print("Here ae your random passwords:")
for x in range(nbrofpwds):
    pwd =""
    for chars in range(pwdlen):
        pwd =pwd+random.choice(randomchars)
    print(pwd)
# Out:
# welcome to random password generator!
# please enter a number of passwords to be generated: 3
# please enter the lenght of the password needed: 11
# Here ae your random passwords:
# Ga4WjLbdeJ*
# n$G&bd8UqIk
# HB1R$D&Nh!t
